# %% [markdown]
#  ## General Assembly - 21st Nov 2017 ##
#
# This notebook contains exercises for getting started with visualising data analysis in Python. The 3 main topics we will cover in this class are:
# 1. Reading in data from different sources
# 2. Manipulating data in Python
# 3. Visualising data in Python

# %% [markdown]
# ### Reading in data from different sources
# 1. Reading in from a URL
# 2. Reading in from an excel spreadsheet
# 3. Reading in from a csv

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib

# %%
# 2. Specify the URL for the Iris dataset (UCI Machine Learning Repository)
url = "http://goo.gl/HppjFh"

# 3. Download the file
raw_data = urllib.request.urlopen(url)

# 4. Load the CSV file as a numpy matrix
#dataset = pd.read_csv(raw_data, delimiter=",")
dataset = pd.read_csv(raw_data, delimiter=",", names=('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))
#print(dataset.shape)
dataset.head()

# Refer to http://pandas.pydata.org/pandas-docs/version/0.15.0/io.html#io-read-csv-table
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Read data from an excel spreadsheet
# 1. Load the file into python
xl = pd.ExcelFile("iris.xlsx")
# 2. Find what sheets are in the workbook
xl.sheet_names
# Out:
# ['iris']

# %%
# 3. Read in the dataset from the 'Iris' sheet
df = xl.parse("iris")
df.head()
df.shape
# Out:
# (150, 5)

# %%
# Bonus: To write the file to excel format we can use the 'to_excel' method
df.to_excel('iris_saved_v2.xlsx', sheet_name='Sheet1')

# %%
# Read data from a csv
iris_data = pd.read_csv('iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#  To write the file to csv format we can use the 'to_csv' method
df.to_csv('iris_saved.csv')

# %% [markdown]
# ### Manipulating Data in Python
# In this section we will begin summarise the data and get an idea of the distribution of our data and what type of cleaning it requires. This is an essential step of a data science project

# %%
# Get a count of the number of rows in the DataFrame
len(iris_data.index)
# Out:
# 150

# %%
# Get the dimensions of the DataFrame
iris_data.shape
# Out:
# (150, 6)

# %%
# Summarise the data
iris_data.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    74.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      0.000000      4.300000     2.000000      1.000000     0.100000
# 25%     37.250000      5.100000     2.800000      1.600000     0.300000
# 50%     74.500000      5.800000     3.000000      4.350000     1.300000
# 75%    111.750000      6.400000     3.300000      5.100000     1.800000
# max    149.000000      7.900000     4.400000      6.900000     2.500000

# %%
# Select only the observations with petal_length < 1.7
iris_data[(iris_data['petal_length']<1.7)]
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0            0           5.1          3.5           1.4          0.2  setosa
# 1            1           4.9          3.0           1.4          0.2  setosa
# 2            2           4.7          3.2           1.3          0.2  setosa
# 3            3           4.6          3.1           1.5          0.2  setosa
# 4            4           5.0          3.6           1.4          0.2  setosa
# 6            6           4.6          3.4           1.4          0.3  setosa
# 7            7           5.0          3.4           1.5          0.2  setosa
# 8            8           4.4          2.9           1.4          0.2  setosa
# 9            9           4.9          3.1           1.5          0.1  setosa
# 10          10           5.4          3.7           1.5          0.2  setosa
# 11          11           4.8          3.4           1.6          0.2  setosa
# 12          12           4.8          3.0           1.4          0.1  setosa
# 13          13           4.3          3.0           1.1          0.1  setosa
# 14          14           5.8          4.0           1.2          0.2  setosa
# 15          15           5.7          4.4           1.5          0.4  setosa
# 16          16           5.4          3.9           1.3          0.4  setosa
# 17          17           5.1          3.5           1.4          0.3  setosa
# 19          19           5.1          3.8           1.5          0.3  setosa
# 21          21           5.1          3.7           1.5          0.4  setosa
# 22          22           4.6          3.6           1.0          0.2  setosa
# 25          25           5.0          3.0           1.6          0.2  setosa
# 26          26           5.0          3.4           1.6          0.4  setosa
# 27          27           5.2          3.5           1.5          0.2  setosa
# 28          28           5.2          3.4           1.4          0.2  setosa
# 29          29           4.7          3.2           1.6          0.2  setosa
# 30          30           4.8          3.1           1.6          0.2  setosa
# 31          31           5.4          3.4           1.5          0.4  setosa
# 32          32           5.2          4.1           1.5          0.1  setosa
# 33          33           5.5          4.2           1.4          0.2  setosa
# 34          34           4.9          3.1           1.5          0.1  setosa
# 35          35           5.0          3.2           1.2          0.2  setosa
# 36          36           5.5          3.5           1.3          0.2  setosa
# 37          37           4.9          3.1           1.5          0.1  setosa
# 38          38           4.4          3.0           1.3          0.2  setosa
# 39          39           5.1          3.4           1.5          0.2  setosa
# 40          40           5.0          3.5           1.3          0.3  setosa
# 41          41           4.5          2.3           1.3          0.3  setosa
# 42          42           4.4          3.2           1.3          0.2  setosa
# 43          43           5.0          3.5           1.6          0.6  setosa
# 45          45           4.8          3.0           1.4          0.3  setosa
# 46          46           5.1          3.8           1.6          0.2  setosa
# 47          47           4.6          3.2           1.4          0.2  setosa
# 48          48           5.3          3.7           1.5          0.2  setosa
# 49          49           5.0          3.3           1.4          0.2  setosa

# %%
# Now let's group the data by the species
byspecies = iris_data.groupby('species')
byspecies.describe()
# Out:
#            Unnamed: 0                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# species
# setosa           50.0   24.5  14.57738    0.0   12.25   24.5   36.75   49.0
# versicolor       50.0   74.5  14.57738   50.0   62.25   74.5   86.75   99.0
# virginica        50.0  124.5  14.57738  100.0  112.25  124.5  136.75  149.0
#
#            petal_length        ...  sepal_length      sepal_width         \
#                   count   mean ...           75%  max       count   mean
# species                        ...
# setosa             50.0  1.464 ...           5.2  5.8        50.0  3.418
# versicolor         50.0  4.260 ...           6.3  7.0        50.0  2.770
# virginica          50.0  5.552 ...           6.9  7.9        50.0  2.974
#
#
#                  std  min    25%  50%    75%  max
# species
# setosa      0.381024  2.3  3.125  3.4  3.675  4.4
# versicolor  0.313798  2.0  2.525  2.8  3.000  3.4
# virginica   0.322497  2.2  2.800  3.0  3.175  3.8
#
# [3 rows x 40 columns]

# %%
# Apply a function by a group (Species)
# You can try mean, max, median, etc
byspecies['petal_length'].max()
# Out:
# species
# setosa        1.9
# versicolor    5.1
# virginica     6.9
# Name: petal_length, dtype: float64

# %%
# We can also aggregate by group (makes little sense in this context but this will come in handy)
byspecies['petal_length'].aggregate(np.sum)
# Out:
# species
# setosa         73.2
# versicolor    213.0
# virginica     277.6
# Name: petal_length, dtype: float64

# %%
# We can also aggregate by group (makes little sense in this context but this will come in handy)
byspecies['petal_length'].agg([len, np.mean, np.std])
# Out:
#              len   mean       std
# species
# setosa      50.0  1.464  0.173511
# versicolor  50.0  4.260  0.469911
# virginica   50.0  5.552  0.551895

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114c2a198>]], dtype=object)

# %%
# Install another Python library using pip
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')
# Out:
# /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: 'pandas.tools.plotting.parallel_coordinates' is deprecated, import 'pandas.plotting.parallel_coordinates' instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
# !pip install plotly --upgrade
# Out:
# Requirement already up-to-date: plotly in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages
# Requirement already up-to-date: requests in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: nbformat>=4.2 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: decorator>=4.0.6 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: six in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: pytz in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: certifi>=2017.4.17 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from requests->plotly)
# Requirement already up-to-date: idna<2.7,>=2.5 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from requests->plotly)
# Requirement already up-to-date: chardet<3.1.0,>=3.0.2 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from requests->plotly)
# Requirement already up-to-date: urllib3<1.23,>=1.21.1 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from requests->plotly)
# Requirement already up-to-date: jsonschema!=2.5.0,>=2.4 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from nbformat>=4.2->plotly)
# Requirement already up-to-date: jupyter-core in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from nbformat>=4.2->plotly)
# Requirement already up-to-date: traitlets>=4.1 in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from nbformat>=4.2->plotly)
# Requirement already up-to-date: ipython-genutils in /Users/andrew/miniconda2/envs/keras/lib/python3.5/site-packages (from nbformat>=4.2->plotly)

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.2.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="66367030-642d-43c1-815f-d96dec55eed9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("66367030-642d-43c1-815f-d96dec55eed9", [{"y": [4, 3, 2, 1], "type": "scatter", "x": [1, 2, 3, 4]}], {"title": "hello world"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="c39690b9-d8f9-4822-aa24-dc831ef4c479" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c39690b9-d8f9-4822-aa24-dc831ef4c479", [{"showscale": false, "type": "heatmap", "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]]}], {"margin": {"l": 0, "r": 0, "t": 0, "b": 0}, "xaxis": {"zeroline": false, "gridwidth": 2, "showticklabels": false, "dtick": 1, "tick0": -0.5, "ticks": ""}, "height": 710, "yaxis": {"dtick": 1, "autorange": "reversed", "gridwidth": 2, "tick0": 0.5, "zeroline": false, "showticklabels": false, "ticks": ""}, "annotations": [{"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#ffffff"}, "y": 0, "text": "<b>School</b>", "x": -0.45}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#ffffff"}, "y": 0, "text": "<b>Women</b>", "x": 0.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#ffffff"}, "y": 0, "text": "<b>Men</b>", "x": 1.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#ffffff"}, "y": 0, "text": "<b>Gap</b>", "x": 2.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 1, "text": "MIT", "x": -0.45}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 1, "text": "94", "x": 0.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 1, "text": "152", "x": 1.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 1, "text": "58", "x": 2.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 2, "text": "Stanford", "x": -0.45}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 2, "text": "96", "x": 0.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 2, "text": "151", "x": 1.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 2, "text": "55", "x": 2.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 3, "text": "Harvard", "x": -0.45}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 3, "text": "112", "x": 0.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 3, "text": "165", "x": 1.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 3, "text": "53", "x": 2.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 4, "text": "U.Penn", "x": -0.45}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow": false, "xref": "x1", "font": {"color": "#000000"}, "y": 4, "text": "92", "x": 0.55}, {"yref": "y1", "xanchor": "left", "align": "left", "showarrow ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="609aa543-648f-4153-91ae-a7ca3255875d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("609aa543-648f-4153-91ae-a7ca3255875d", [{"y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="d6473b63-30c8-4524-89fb-461fc97bc3bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d6473b63-30c8-4524-89fb-461fc97bc3bd", [{"y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "marker": {"color": "#ffcdd2"}, "type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "name": "Women"}, {"y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81],